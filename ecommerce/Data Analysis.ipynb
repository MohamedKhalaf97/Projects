# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/Ecommerce.csv')
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
for col in df.columns:
    print(f'For column {col}\n----------------\n')
    print(df[col].value_counts())
    print('\n')
# Out:
# For column ID
# ----------------
#
# 2047     1
# 3355     1
# 7465     1
# 5416     1
# 9510     1
#         ..
# 10848    1
# 4703     1
# 6750     1
# 605      1
# 2049     1
# Name: ID, Length: 10999, dtype: int64
#
#
# For column Warehouse_block
# ----------------
#
# F    3666
# D    1834
# B    1833
# C    1833
# A    1833
# Name: Warehouse_block, dtype: int64
#
#
# For column Mode_of_Shipment
# ----------------
#
# Ship      7462
# Flight    1777
# Road      1760
# Name: Mode_of_Shipment, dtype: int64
#
#
# For column Customer_care_calls
# ----------------
#
# 4    3557
# 3    3217
# 5    2328
# 6    1013
# 2     638
# 7     246
# Name: Customer_care_calls, dtype: int64
#
#
# For column Customer_rating
# ----------------
#
# 3    2239
# 1    2235
# 4    2189
# 5    2171
# 2    2165
# Name: Customer_rating, dtype: int64
#
#
# For column Cost_of_the_Product
# ----------------
#
# 245    110
# 257    109
# 260    106
# 254    101
# 264    100
#       ...
# 99       5
# ...

# %%
for col in df.columns:
    print(f'For column {col}\n----------------\n')
    print(df[col].unique())
    print('\n')
# Out:
# For column ID
# ----------------
#
# [    1     2     3 ... 10997 10998 10999]
#
#
# For column Warehouse_block
# ----------------
#
# ['D' 'F' 'A' 'B' 'C']
#
#
# For column Mode_of_Shipment
# ----------------
#
# ['Flight' 'Ship' 'Road']
#
#
# For column Customer_care_calls
# ----------------
#
# [4 2 3 5 6 7]
#
#
# For column Customer_rating
# ----------------
#
# [2 5 3 1 4]
#
#
# For column Cost_of_the_Product
# ----------------
#
# [177 216 183 176 184 162 250 233 150 164 189 232 198 275 152 227 143 239
#  145 161 156 211 251 225 172 234 266 257 223 149 137 181 215 269 139 174
#  151 210 169 160 190 141 165 170 203 246 238 193 221 179 105 261 202 109
#  158 231 206 187 230 113 180 132 217 197 185 278 229 186 286 175 219 213
#  235 271 144 218 263 168 265 205 252 222 220 147 200 224 247 280 157 207
#  237 264 248 191 146 135  98  97 114 112 274 166 148 270 242 192 116 255
#  209 134 130 133 140 136 142 154 155 127 129 159 294 226 258 241 208 182
# ...

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
df.tail()
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10994                1                  252                5
# 10995                1                  232                5
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 10994             medium      F                 1           1538
# ...

# %%
print(df.shape)
# Out:
# (10999, 12)

# %%
df.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %% [markdown]
# # Sorting

# %%
df.sort_values(['Discount_offered', 'Customer_rating'], ascending=[True, False])
# Out:
#         ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 12      13               D           Flight                    3
# 1233  1234               B           Flight                    3
# 1345  1346               F             Road                    3
# 1907  1908               F             Road                    4
# 2174  2175               A             Road                    3
# ...    ...             ...              ...                  ...
# 956    957               A           Flight                    4
# 1302  1303               D             Ship                    4
# 1328  1329               A             Ship                    5
# 1484  1485               A             Road                    3
# 2897  2898               F             Ship                    4
#
#       Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 12                  5                  198                3
# 1233                5                  176                3
# ...

# %%
df.sort_values(['Discount_offered', 'Cost_of_the_Product'], ascending=[True, False])
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 4819    4820               F             Ship                    6
# 8907    8908               B           Flight                    2
# 10194  10195               D             Ship                    6
# 6888    6889               D             Ship                    7
# 5531    5532               F             Ship                    6
# ...      ...             ...              ...                  ...
# 2823    2824               B             Ship                    2
# 358      359               C             Ship                    3
# 740      741               A             Ship                    4
# 2781    2782               B             Ship                    4
# 276      277               D           Flight                    4
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 4819                 5                  310                4
# ...

# %%
df.sort_values(['Discount_offered', 'Prior_purchases'], ascending=[True, False])
# Out:
#         ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 3177  3178               B             Ship                    2
# 3588  3589               D             Ship                    4
# 3591  3592               B             Ship                    2
# 3600  3601               D             Ship                    3
# 3823  3824               F             Road                    3
# ...    ...             ...              ...                  ...
# 2161  2162               F             Ship                    4
# 2417  2418               F             Ship                    3
# 2696  2697               A             Ship                    4
# 2823  2824               B             Ship                    2
# 2897  2898               F             Ship                    4
#
#       Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 3177                1                  274               10
# 3588                3                  185               10
# ...

# %% [markdown]
# # Subsetting

# %% [markdown]
# ### Subsetting based on Warehouse_block

# %%
df['Warehouse_block'].unique()
# Out:
# array(['D', 'F', 'A', 'B', 'C'], dtype=object)

# %%
df[df['Warehouse_block'] == 'A']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 2          3               A           Flight                    2
# 8          9               A           Flight                    3
# 14        15               A           Flight                    4
# 20        21               A             Ship                    3
# 26        27               A             Ship                    4
# ...      ...             ...              ...                  ...
# 10970  10971               A           Flight                    4
# 10976  10977               A           Flight                    3
# 10982  10983               A             Ship                    5
# 10988  10989               A             Ship                    4
# 10994  10995               A             Ship                    4
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 2                    2                  183                4
# ...

# %%
df[df['Warehouse_block'] == 'B']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 3          4               B           Flight                    3
# 9         10               B           Flight                    3
# 15        16               B           Flight                    4
# 21        22               B             Ship                    3
# 27        28               B             Ship                    5
# ...      ...             ...              ...                  ...
# 10971  10972               B           Flight                    5
# 10977  10978               B             Ship                    5
# 10983  10984               B             Ship                    4
# 10989  10990               B             Ship                    5
# 10995  10996               B             Ship                    4
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 3                    3                  176                4
# ...

# %%
df[df['Warehouse_block'] == 'C']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 4          5               C           Flight                    2
# 10        11               C           Flight                    3
# 16        17               C           Flight                    3
# 22        23               C             Ship                    2
# 28        29               C             Ship                    2
# ...      ...             ...              ...                  ...
# 10972  10973               C           Flight                    4
# 10978  10979               C             Ship                    4
# 10984  10985               C             Ship                    5
# 10990  10991               C             Ship                    5
# 10996  10997               C             Ship                    5
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 4                    2                  184                3
# ...

# %%
df[df['Warehouse_block'] == 'D']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 6          7               D           Flight                    3
# 12        13               D           Flight                    3
# 18        19               D             Ship                    5
# 24        25               D             Ship                    4
# ...      ...             ...              ...                  ...
# 10974  10975               D           Flight                    5
# 10980  10981               D             Ship                    4
# 10986  10987               D             Ship                    4
# 10992  10993               D             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df[df['Warehouse_block'] == 'F']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 1          2               F           Flight                    4
# 5          6               F           Flight                    3
# 7          8               F           Flight                    4
# 11        12               F           Flight                    4
# 13        14               F           Flight                    4
# ...      ...             ...              ...                  ...
# 10985  10986               F             Ship                    5
# 10987  10988               F             Ship                    5
# 10991  10992               F             Ship                    5
# 10993  10994               F             Ship                    5
# 10997  10998               F             Ship                    5
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 1                    5                  216                2
# ...

# %% [markdown]
# ### Subsetting based on Mode Of Shipment

# %%
df['Mode_of_Shipment'].unique()
# Out:
# array(['Flight', 'Ship', 'Road'], dtype=object)

# %%
df[df['Mode_of_Shipment'] == 'Flight']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10972  10973               C           Flight                    4
# 10973  10974               F           Flight                    5
# 10974  10975               D           Flight                    5
# 10975  10976               F           Flight                    5
# 10976  10977               A           Flight                    3
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df[df['Mode_of_Shipment'] == 'Ship']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 17        18               F             Ship                    5
# 18        19               D             Ship                    5
# 19        20               F             Ship                    4
# 20        21               A             Ship                    3
# 21        22               B             Ship                    3
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 17                   5                  227                3
# ...

# %%
df[df['Mode_of_Shipment'] == 'Road']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 110      111               A             Road                    3
# 111      112               B             Road                    4
# 112      113               C             Road                    4
# 113      114               F             Road                    3
# 114      115               D             Road                    3
# ...      ...             ...              ...                  ...
# 10950  10951               D             Road                    4
# 10951  10952               F             Road                    5
# 10952  10953               A             Road                    5
# 10953  10954               B             Road                    4
# 10954  10955               C             Road                    4
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 110                  1                  158                2
# ...

# %% [markdown]
# ### Subsetting based on Product Importance

# %%
df[df['Product_importance'] == 'low']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 6          7               D           Flight                    3
# 7          8               F           Flight                    4
# ...      ...             ...              ...                  ...
# 10988  10989               A             Ship                    4
# 10990  10991               C             Ship                    5
# 10993  10994               F             Ship                    5
# 10996  10997               C             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df[df['Product_importance'] == 'medium']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# 5          6               F           Flight                    3
# 9         10               B           Flight                    3
# 10        11               C           Flight                    3
# ...      ...             ...              ...                  ...
# 10991  10992               F             Ship                    5
# 10992  10993               D             Ship                    5
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10997  10998               F             Ship                    5
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 3                    3                  176                4
# ...

# %%
df[df['Product_importance'] == 'high']
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 13        14               F           Flight                    4
# 18        19               D             Ship                    5
# 23        24               F             Ship                    4
# 26        27               A             Ship                    4
# 36        37               D             Ship                    3
# ...      ...             ...              ...                  ...
# 10898  10899               A             Ship                    4
# 10908  10909               D             Ship                    4
# 10910  10911               A             Ship                    5
# 10956  10957               D           Flight                    4
# 10958  10959               A           Flight                    5
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 13                   4                  275                3
# ...

# %% [markdown]
# ### Subsetting based on Discount_offered

# %%
df[df['Discount_offered'] > 30]
# Out:
#         ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0        1               D           Flight                    4
# 1        2               F           Flight                    4
# 2        3               A           Flight                    2
# 4        5               C           Flight                    2
# 7        8               F           Flight                    4
# ...    ...             ...              ...                  ...
# 3125  3126               F             Road                    4
# 3126  3127               D             Road                    3
# 3130  3131               C             Road                    6
# 3131  3132               F             Road                    4
# 3133  3134               F             Road                    3
#
#       Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                   2                  177                3
# 1                   5                  216                2
# ...

# %% [markdown]
# ### Subsetting on Multiple conditions

# %%
df[(df["Customer_rating"] == 5) & (df["Mode_of_Shipment"]=="Flight")]
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 1          2               F           Flight                    4
# 11        12               F           Flight                    4
# 12        13               D           Flight                    3
# 135      136               B           Flight                    3
# 137      138               F           Flight                    3
# ...      ...             ...              ...                  ...
# 10833  10834               B           Flight                    6
# 10955  10956               F           Flight                    2
# 10963  10964               F           Flight                    4
# 10966  10967               C           Flight                    5
# 10971  10972               B           Flight                    5
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 1                    5                  216                2
# ...

# %% [markdown]
# ### Subsetting using .isin()

# %%
GenderFilter = df['Gender'].isin(['M'])
df[GenderFilter]
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 10        11               C           Flight                    3
# 13        14               F           Flight                    4
# ...      ...             ...              ...                  ...
# 10986  10987               D             Ship                    4
# 10990  10991               C             Ship                    5
# 10991  10992               F             Ship                    5
# 10992  10993               D             Ship                    5
# 10997  10998               F             Ship                    5
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 1                    5                  216                2
# ...

# %% [markdown]
# ### Multiple parameter Filtering

# %%
ModeOfShipmentFilter = df['Mode_of_Shipment'].isin(['Flight', 'Ship'])

WarehouseBlockFilter = df["Warehouse_block"].isin(["D", "A"])

df[ModeOfShipmentFilter & WarehouseBlockFilter]
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 2          3               A           Flight                    2
# 6          7               D           Flight                    3
# 8          9               A           Flight                    3
# 12        13               D           Flight                    3
# ...      ...             ...              ...                  ...
# 10986  10987               D             Ship                    4
# 10988  10989               A             Ship                    4
# 10992  10993               D             Ship                    5
# 10994  10995               A             Ship                    4
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %% [markdown]
# # Summary statistics

# %%
df['Discount_offered'].mean()
# Out:
# 13.37321574688608

# %%
df['Discount_offered'].median()
# Out:
# 7.0

# %%
df['Discount_offered'].mode()
# Out:
# 0    10
# dtype: int64

# %%
df['Discount_offered'].min()
# Out:
# 1

# %%
df['Discount_offered'].max()
# Out:
# 65

# %%
df['Discount_offered'].var()
# Out:
# 262.61910796137164

# %%
df['Discount_offered'].std()
# Out:
# 16.20552708064047

# %%
df['Discount_offered'].sum()
# Out:
# 147092

# %%
df['Discount_offered'].quantile()
# Out:
# 7.0

# %% [markdown]
# # Grouped Summuries

# %%
df.groupby(['Warehouse_block','Mode_of_Shipment','Product_importance'])['Discount_offered'].agg([min, max, np.mean, np.median,sum, np.std, np.var])
# Out:
#                                                      min  max       mean  \
# Warehouse_block Mode_of_Shipment Product_importance
# A               Flight           high                  2   65  14.322581
#                                  low                   1   63  11.868056
#                                  medium                1   62  14.122951
#                 Road             high                  1   61  16.222222
#                                  low                   1   65  13.131034
#                                  medium                1   64  12.524590
#                 Ship             high                  1   65  16.691589
#                                  low                   1   65  13.793548
#                                  medium                1   65  11.947573
# B               Flight           high                  1   63  14.520000
#                                  low                   1   63  10.672000
# ...

# %%
df.groupby(['Warehouse_block','Mode_of_Shipment','Product_importance'])['Discount_offered'].describe()
# Out:
#                                                       count       mean  \
# Warehouse_block Mode_of_Shipment Product_importance
# A               Flight           high                  31.0  14.322581
#                                  low                  144.0  11.868056
#                                  medium               122.0  14.122951
#                 Road             high                  27.0  16.222222
#                                  low                  145.0  13.131034
#                                  medium               122.0  12.524590
#                 Ship             high                 107.0  16.691589
#                                  low                  620.0  13.793548
#                                  medium               515.0  11.947573
# B               Flight           high                  25.0  14.520000
#                                  low                  125.0  10.672000
# ...

# %%
df.groupby(['Warehouse_block','Mode_of_Shipment','Product_importance'])['Discount_offered'].describe().transpose()
# Out:
# Warehouse_block             A                                                 \
# Mode_of_Shipment       Flight                               Road
# Product_importance       high         low      medium       high         low
# count               31.000000  144.000000  122.000000  27.000000  145.000000
# mean                14.322581   11.868056   14.122951  16.222222   13.131034
# std                 18.358263   13.967618   16.416369  17.930064   16.708387
# min                  2.000000    1.000000    1.000000   1.000000    1.000000
# 25%                  5.000000    4.000000    5.000000   5.000000    3.000000
# 50%                  7.000000    7.000000    8.000000   9.000000    7.000000
# 75%                  9.500000   10.000000   10.000000  22.500000   10.000000
# max                 65.000000   63.000000   62.000000  61.000000   65.000000
#
# Warehouse_block                                                            B  \
# ...

# %%
df.groupby(['Warehouse_block','Mode_of_Shipment','Product_importance'])['Discount_offered'].describe().transpose()['B']
# Out:
# Mode_of_Shipment       Flight                               Road              \
# Product_importance       high         low      medium       high         low
# count               25.000000  125.000000  146.000000  29.000000  132.000000
# mean                14.520000   10.672000   13.890411  12.172414   12.863636
# std                 18.264538   14.160244   16.044818  14.089178   15.430105
# min                  1.000000    1.000000    1.000000   1.000000    1.000000
# 25%                  4.000000    3.000000    4.000000   3.000000    4.000000
# 50%                  7.000000    6.000000    7.000000   7.000000    7.000000
# 75%                 13.000000    9.000000   13.750000  10.000000   10.500000
# max                 63.000000   63.000000   64.000000  54.000000   65.000000
#
# Mode_of_Shipment                     Ship
# Product_importance      medium       high         low      medium
# count               133.000000  92.000000  598.000000  553.000000
# ...

# %%
regionFilter = df.groupby('Warehouse_block')['Discount_offered'].max()
regionFilter
# Out:
# Warehouse_block
# A    65
# B    65
# C    65
# D    65
# F    65
# Name: Discount_offered, dtype: int64

# %% [markdown]
# # Pivot Table

# %%
df.pivot_table(index=["Warehouse_block",'Mode_of_Shipment','Product_importance'], aggfunc=[min, max, np.mean, np.median,sum, np.std, np.var], values="Discount_offered")
# Out:
#                                                                  min  \
#                                                     Discount_offered
# Warehouse_block Mode_of_Shipment Product_importance
# A               Flight           high                              2
#                                  low                               1
#                                  medium                            1
#                 Road             high                              1
#                                  low                               1
#                                  medium                            1
#                 Ship             high                              1
#                                  low                               1
#                                  medium                            1
# B               Flight           high                              1
#                                  low                               1
# ...

# %%
pd.pivot_table(df, index=['Mode_of_Shipment','Product_importance'], columns='Warehouse_block', values='Discount_offered')
# Out:
# Warehouse_block                              A          B          C  \
# Mode_of_Shipment Product_importance
# Flight           high                14.322581  14.520000  12.361111
#                  low                 11.868056  10.672000  13.588235
#                  medium              14.122951  13.890411  11.878049
# Road             high                16.222222  12.172414  14.481481
#                  low                 13.131034  12.863636  14.367347
#                  medium              12.524590  13.398496  12.825000
# Ship             high                16.691589  15.467391  13.695238
#                  low                 13.793548  13.050167  12.656514
#                  medium              11.947573  13.358047  14.321168
#
# Warehouse_block                              D          F
# Mode_of_Shipment Product_importance
# Flight           high                 9.333333  14.808511
#                  low                 13.376712  12.864111
# ...

# %% [markdown]
# # Explicit Indexes

# %%
ModeofShipmentFilter = df.set_index(['Mode_of_Shipment'])
ModeofShipmentFilter
# Out:
#                      ID Warehouse_block  Customer_care_calls  Customer_rating  \
# Mode_of_Shipment
# Flight                1               D                    4                2
# Flight                2               F                    4                5
# Flight                3               A                    2                2
# Flight                4               B                    3                3
# Flight                5               C                    2                2
# ...                 ...             ...                  ...              ...
# Ship              10995               A                    4                1
# Ship              10996               B                    4                1
# Ship              10997               C                    5                4
# Ship              10998               F                    5                2
# Ship              10999               D                    2                5
#
# ...

# %%
Product_importance = df.set_index(['Product_importance'])
Product_importance.loc[['high', 'low']]
# Out:
#                        ID Warehouse_block Mode_of_Shipment  \
# Product_importance
# high                   14               F           Flight
# high                   19               D             Ship
# high                   24               F             Ship
# high                   27               A             Ship
# high                   37               D             Ship
# ...                   ...             ...              ...
# low                 10989               A             Ship
# low                 10991               C             Ship
# low                 10994               F             Ship
# low                 10997               C             Ship
# low                 10999               D             Ship
#
#                     Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# Product_importance
# high                                  4                4                  275
# ...

# %% [markdown]
# # Save Data

# %%
df.to_csv('data/Ecommerce2.csv')
